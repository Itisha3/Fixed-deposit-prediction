# %%
from datetime import datetime,timedelta
vehicle={'bikes':2, 'cycle':3, 'car':1, 'boat':2}

class Customer:
    def __init__ (self,Customer_Name,Phone_Number,Email):
        self.Customer_Name=Customer_Name
        self.Phone_Number=Phone_Number
        self.Email=Email
    
    
class Rental(object):
        
    def reserve(self,index):
        #TODO raise exception when invalid index
        self._reserved.add(index)
        
    def unreserve(self,index):
        #TODO raise exception when invalid index
        self._reserved.remove(index)
    
    def save(self):
        #TODO
        pass
        
    def load(self):
        #TODO
        pass

    def bikes(index):
        #for bike inventory
        for i in range(2):
            if (i==0):
                print("{vehicle} is not available in inventory")
            else:
                print(unreserve(),"{vehicle} is available in inventory")
                
    def cars(index):
        #for car inventory
        for i in range(1):
            if (i==0):
                 print("{vehicle} is not available in inventory")
            else:
                print(unreserve(),"{vehicle} is available in inventory")
                
    def cycles(index):
        #for cycle inventory
        for i in range(3):
            if (i==0):
                 print("\n{vehicle} is not available in inventory")
            else:
                print("\n{vehicle} is available in inventory",unreserve())
                
    def boat(index):
        #for boat inventory
        for i in range(2):
            if (i==0):
                 print("{vehicle} is not available in inventory")
            else:
                print(unreserve(),"{vehicle} is available in inventory")

                
#Taking inputs from customer
Customer_Name=input("Enter Customer Name:",Customer.Customer_Name)
Phone_Number=int(input("Enter Customer Phone Number:",Customer.Phoner_Number))
Email=input("Enter Customer Email ID:",Customer.Email)
my_date=input('Enter date(yyyy-mm-dd hh:mm): ')

#Rental_date and return_date
rental_date = datetime.strptime(my_date, "%Y-%M-%D %H:%M")
for t in range(5):
    ret=datetime.today()+timedelta(t)
return_date=datetime.strptime(ret,"%Y-%M-%M %H:%M")

print("\n Enter the date you want to rent:",rental_date)

ch=print("Enter \n 1.Bikes \n 2. Cars \n 3. Cycles \n 4. Boat")
if (ch==1):
    bikes()
elif(ch==2):
    cars()
elif(ch==3):
    cycles()
elif(ch==4):
    boat()
else:
    print("\nWrong choice!!")
# Out:
# 'def __str__(self):\n        out=""\n        for i in self._seats:\n            if i in self._reserved:\n                out+="*"+str(i)+"* "\n            else:\n                out+=str(i)+" "\n        return out\n\nif __name__=="__main__":\n    s=Seats()\n    print (s)\n    s.reserve(3)\n    print (s)\n    s.reserve(1)\n    print (s)\n    s.unreserve(1)\n    print (s)'
